# %% [markdown]
# <a href="https://colab.research.google.com/github/UknowYunmo/Image-Processing/blob/main/09-OpenCV_%ED%85%8C%EB%91%90%EB%A6%AC(Contours).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# contour : 외곽, 테두리
# -> 사진의 테두리 부분
#
# - 이걸로 사진 내의 숫자, 글자를 인식할 수 있다

# %%
cv2.findContours(image,mode,method) # 이미지에서 Contour들을 찾는 함수

# %% [markdown]
# - mode : Contour들을 찾는 방법
#
# RETR_EXTERNAL : 바깥쪽 Line만 찾기
#
# RETR_LIST : 모든 Line을 찾지만, Hierarchy 구성 X
#
# RETR_TREE : 모든 Line을 찾으며, 모든 Hierarchy 구성 O
#
# - mehtod : Contour들을 찾는 근사치 방법
#
# CHAIN_APPROX_NONE : 모든 Contour 포인트 저장
#
# CHAIN_APPROX_SIMPLE : Countour Line을 그릴 수 있는 포인트만 저장
#
# 입력 이미지는 Gray Scale Threshold 전처리 과정이 필요하다.

# %%
cv2.drawContours(image,contours,contour_index,color,thickness) # Contour들을 그리는 함수

# %% [markdown]
# - contour_index : 그리고자 하는 Contours Line (전체 : -1)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ec381897-f028-46a4-a7ec-423856cf431e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec381897-f028-46a4-a7ec-423856cf431e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving background.jpg to background.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('images.jfif')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(image_gray, 127, 255, 0)

plt.imshow(cv2.cvtColor(thresh, cv2.COLOR_GRAY2RGB))
plt.show()

contours = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)[0]
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 4)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

image = cv2.imread('images.jfif')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(image_gray, 127, 255, 0)
contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
cv2.drawContours(image, contours, -1, (0, 255, 0), 4)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

image = cv2.imread('images.jfif')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(image_gray, 127, 255, 0)
contours = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[0]
cv2.drawContours(image, contours, -1, (0, 255, 0), 4)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
