# %% [markdown]
# <a href="https://colab.research.google.com/github/UknowYunmo/Image-Processing/blob/main/05-OpenCV_%EC%9D%B4%EB%AF%B8%EC%A7%80%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이미지를 합치는 두 가지 방법
# 1. cv2.add() : Saturation 연산을 수행
# -> 0보다 작으면 0, 255보다 크면 255로 표현
# 2. np.add() : Modulo 연산을 수행
# -> 256은 0, 257부터 다시 1부터 시작

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e781ef80-b532-4571-afbc-ffd648cfd859" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e781ef80-b532-4571-afbc-ffd648cfd859">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jfif to images.jfif

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6d463edf-e17b-4b41-84e8-4bf62b913581" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d463edf-e17b-4b41-84e8-4bf62b913581">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving background.jpg to background.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image=cv2.imread('images.jfif')
image2=cv2.imread('background.jpg')

result=cv2.add(image,image2)
plt.imshow(cv2.cvtColor(result,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-82d667285381> in <module>()
#       5 image2=cv2.imread('background.jpg')
#       6
# ----> 7 result=cv2.add(image,image2)
#       8 plt.imshow(cv2.cvtColor(result,cv2.COLOR_BGR2RGB))
#       9 plt.show()
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/arithm.cpp:663: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %% [markdown]
# 해보니까 위 사진들의 크기가 같지 않으면 오류가 발생한다. 저번에 배운 resize로 동일한 사이즈로 맞춰주자

# %%
import cv2
import matplotlib.pyplot as plt

image=cv2.imread('images.jfif')
image2=cv2.imread('background.jpg')

print(image.shape)
print(image2.shape)

image_1=cv2.resize(image,(300,250),interpolation=cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(image_1,cv2.COLOR_BGR2RGB))
plt.show()

image_2=cv2.resize(image2,(300,250),interpolation=cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(image_2,cv2.COLOR_BGR2RGB))
plt.show()

result=cv2.add(image_1,image_2)
plt.imshow(cv2.cvtColor(result,cv2.COLOR_BGR2RGB))
plt.show()

result=image_1+image_2
plt.imshow(cv2.cvtColor(result,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (174, 289, 3)
# (417, 626, 3)
